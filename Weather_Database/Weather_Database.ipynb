# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities= []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=16e34dcfc7159480f1213698b71d7f8a'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city = "Boston"
test_url = f"{url}&q={city}"
test_json = requests.get(test_url).json()
test_json
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 31.84,
#   'feels_like': 22.3,
#   'temp_min': 29.66,
#   'temp_max': 33.75,
#   'pressure': 1006,
#   'humidity': 81},
#  'visibility': 10000,
#  'wind': {'speed': 12.66, 'deg': 300},
#  'clouds': {'all': 100},
#  'dt': 1673909838,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1673871021,
#   'sunset': 1673905024},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | eydhafushi
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | pringsewu
# Processing Record 6 of Set 1 | kavieng
# Processing Record 7 of Set 1 | port macquarie
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | klaksvik
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | dalvik
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | tutoia
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | los llanos de aridane
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | sao felix do xingu
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | omutinskoye
# City not found. Skipping...
# Processing Record 34 of Set 1 | ahipara
# Processing Record 35 of Set 1 | reconquista
# Processing Record 36 of Set 1 | menongue
# Processing Record 37 of Set 1 | bandundu
# Processing Record 38 of Set 1 | marawi
# Processing Record 39 of Set 1 | almazar
# Processing Record 40 of Set 1 | esso
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | ankang
# Processing Record 43 of Set 1 | miandrivazo
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | roald
# Processing Record 46 of Set 1 | nova olimpia
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | nalut
# Processing Record 49 of Set 1 | ulaanbaatar
# Processing Record 50 of Set 1 | crib point
# Processing Record 1 of Set 2 | coquimbo
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | padang
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | poya
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | ittiri
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | lang son
# Processing Record 13 of Set 2 | okhotsk
# Processing Record 14 of Set 2 | sitka
# Processing Record 15 of Set 2 | el espinal
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | kisangani
# Processing Record 19 of Set 2 | goroka
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | fallon
# Processing Record 23 of Set 2 | port lincoln
# Processing Record 24 of Set 2 | dunedin
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | ponta do sol
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | kemi
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 31 of Set 2 | cayenne
# Processing Record 32 of Set 2 | sinnamary
# Processing Record 33 of Set 2 | camopi
# Processing Record 34 of Set 2 | buon me thuot
# City not found. Skipping...
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | taltal
# Processing Record 37 of Set 2 | lata
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | pangody
# Processing Record 40 of Set 2 | skagen
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | vorukh
# Processing Record 43 of Set 2 | matay
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | urumqi
# Processing Record 46 of Set 2 | esperance
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | namatanai
# Processing Record 50 of Set 2 | kismayo
# Processing Record 1 of Set 3 | lavrentiya
# Processing Record 2 of Set 3 | sao filipe
# Processing Record 3 of Set 3 | riyadh
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | bardiyah
# Processing Record 7 of Set 3 | srednekolymsk
# Processing Record 8 of Set 3 | marathon
# Processing Record 9 of Set 3 | codrington
# Processing Record 10 of Set 3 | solsona
# Processing Record 11 of Set 3 | puerto carreno
# Processing Record 12 of Set 3 | dongying
# Processing Record 13 of Set 3 | yulara
# Processing Record 14 of Set 3 | caarapo
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | popondetta
# Processing Record 17 of Set 3 | clonakilty
# Processing Record 18 of Set 3 | tres arroyos
# Processing Record 19 of Set 3 | kruisfontein
# Processing Record 20 of Set 3 | slave lake
# Processing Record 21 of Set 3 | louisville
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | kalmunai
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | kalmar
# Processing Record 26 of Set 3 | cap malheureux
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | kavaratti
# Processing Record 29 of Set 3 | troitsko-pechorsk
# Processing Record 30 of Set 3 | porto novo
# Processing Record 31 of Set 3 | lamongan
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | chingola
# Processing Record 34 of Set 3 | pozo colorado
# Processing Record 35 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | suez
# Processing Record 38 of Set 3 | balaipungut
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | abu zabad
# Processing Record 41 of Set 3 | san andres
# Processing Record 42 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 3 | rawson
# Processing Record 44 of Set 3 | puerto escondido
# Processing Record 45 of Set 3 | raudeberg
# Processing Record 46 of Set 3 | trebic
# Processing Record 47 of Set 3 | luis correia
# Processing Record 48 of Set 3 | ormara
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | beitbridge
# Processing Record 1 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 2 of Set 4 | palmer
# Processing Record 3 of Set 4 | eyl
# Processing Record 4 of Set 4 | sokolo
# Processing Record 5 of Set 4 | mareeba
# Processing Record 6 of Set 4 | tiarei
# Processing Record 7 of Set 4 | smithers
# Processing Record 8 of Set 4 | caravelas
# Processing Record 9 of Set 4 | vila velha
# Processing Record 10 of Set 4 | kisesa
# Processing Record 11 of Set 4 | dir
# Processing Record 12 of Set 4 | mweka
# Processing Record 13 of Set 4 | baijiantan
# Processing Record 14 of Set 4 | aksehir
# Processing Record 15 of Set 4 | saint-georges
# Processing Record 16 of Set 4 | sobolevo
# Processing Record 17 of Set 4 | barrow
# Processing Record 18 of Set 4 | uray
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | shakhtinsk
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 4 | krasnoselkup
# Processing Record 25 of Set 4 | saquarema
# Processing Record 26 of Set 4 | saint-philippe
# Processing Record 27 of Set 4 | asyut
# Processing Record 28 of Set 4 | coari
# Processing Record 29 of Set 4 | kodiak
# Processing Record 30 of Set 4 | kasempa
# Processing Record 31 of Set 4 | voznesenye
# Processing Record 32 of Set 4 | kwinana
# Processing Record 33 of Set 4 | yar-sale
# Processing Record 34 of Set 4 | zhigansk
# Processing Record 35 of Set 4 | poum
# Processing Record 36 of Set 4 | karratha
# Processing Record 37 of Set 4 | torbay
# Processing Record 38 of Set 4 | tiznit
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | gari
# Processing Record 42 of Set 4 | sept-iles
# Processing Record 43 of Set 4 | aparecida
# Processing Record 44 of Set 4 | aswan
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | bahile
# Processing Record 48 of Set 4 | bengkulu
# Processing Record 49 of Set 4 | cockburn town
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | tual
# Processing Record 2 of Set 5 | inhambane
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | nome
# Processing Record 5 of Set 5 | bilma
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | fairbanks
# Processing Record 8 of Set 5 | nikolayevsk-na-amure
# Processing Record 9 of Set 5 | port alfred
# Processing Record 10 of Set 5 | desaguadero
# Processing Record 11 of Set 5 | sao desiderio
# Processing Record 12 of Set 5 | blairmore
# Processing Record 13 of Set 5 | napanee
# Processing Record 14 of Set 5 | corpus christi
# Processing Record 15 of Set 5 | bathurst
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | labuhan
# Processing Record 18 of Set 5 | dongsheng
# Processing Record 19 of Set 5 | mehamn
# Processing Record 20 of Set 5 | san borja
# Processing Record 21 of Set 5 | new norfolk
# Processing Record 22 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | kenai
# Processing Record 24 of Set 5 | orlik
# Processing Record 25 of Set 5 | cabo san lucas
# Processing Record 26 of Set 5 | farmington
# Processing Record 27 of Set 5 | cururupu
# Processing Record 28 of Set 5 | georgetown
# Processing Record 29 of Set 5 | porto san giorgio
# Processing Record 30 of Set 5 | shingu
# Processing Record 31 of Set 5 | cabedelo
# Processing Record 32 of Set 5 | maralal
# Processing Record 33 of Set 5 | husavik
# Processing Record 34 of Set 5 | tambovka
# Processing Record 35 of Set 5 | tsabong
# Processing Record 36 of Set 5 | pevek
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | marsa matruh
# Processing Record 39 of Set 5 | bredasdorp
# Processing Record 40 of Set 5 | iquique
# Processing Record 41 of Set 5 | sarkand
# Processing Record 42 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 5 | novo aripuana
# Processing Record 44 of Set 5 | tautira
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | campo verde
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | pershotravneve
# Processing Record 49 of Set 5 | catemaco
# Processing Record 50 of Set 5 | phuket
# Processing Record 1 of Set 6 | bara
# Processing Record 2 of Set 6 | mahon
# Processing Record 3 of Set 6 | la ronge
# Processing Record 4 of Set 6 | taoudenni
# Processing Record 5 of Set 6 | tupik
# Processing Record 6 of Set 6 | malangali
# Processing Record 7 of Set 6 | bubaque
# Processing Record 8 of Set 6 | sainte-marie
# Processing Record 9 of Set 6 | fare
# Processing Record 10 of Set 6 | shizunai
# Processing Record 11 of Set 6 | bagdarin
# Processing Record 12 of Set 6 | nuuk
# Processing Record 13 of Set 6 | rusape
# Processing Record 14 of Set 6 | tari
# Processing Record 15 of Set 6 | lugazi
# Processing Record 16 of Set 6 | egvekinot
# Processing Record 17 of Set 6 | kem
# Processing Record 18 of Set 6 | baruun-urt
# Processing Record 19 of Set 6 | tuktoyaktuk
# Processing Record 20 of Set 6 | ossora
# Processing Record 21 of Set 6 | katsuura
# Processing Record 22 of Set 6 | shubarshi
# Processing Record 23 of Set 6 | waipawa
# Processing Record 24 of Set 6 | mantua
# Processing Record 25 of Set 6 | xichang
# Processing Record 26 of Set 6 | hambantota
# Processing Record 27 of Set 6 | hamilton
# Processing Record 28 of Set 6 | severo-kurilsk
# Processing Record 29 of Set 6 | korla
# Processing Record 30 of Set 6 | vestmannaeyjar
# Processing Record 31 of Set 6 | filingue
# Processing Record 32 of Set 6 | kaeo
# Processing Record 33 of Set 6 | gizo
# Processing Record 34 of Set 6 | sao jose da coroa grande
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | tuatapere
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | channel-port aux basques
# Processing Record 41 of Set 6 | rockport
# Processing Record 42 of Set 6 | san cristobal
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | burnie
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | zelenikovo
# Processing Record 47 of Set 6 | muroto
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | bud
# Processing Record 50 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 7 | sioux lookout
# Processing Record 2 of Set 7 | verkh-usugli
# Processing Record 3 of Set 7 | marsh harbour
# Processing Record 4 of Set 7 | ostrovnoy
# Processing Record 5 of Set 7 | bac lieu
# Processing Record 6 of Set 7 | lampazos de naranjo
# Processing Record 7 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 7 | berlevag
# Processing Record 9 of Set 7 | pangnirtung
# Processing Record 10 of Set 7 | lethem
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | lazdijai
# Processing Record 13 of Set 7 | hovd
# Processing Record 14 of Set 7 | north bend
# Processing Record 15 of Set 7 | boali
# Processing Record 16 of Set 7 | tazovskiy
# Processing Record 17 of Set 7 | alto araguaia
# Processing Record 18 of Set 7 | rovaniemi
# Processing Record 19 of Set 7 | yushu
# Processing Record 20 of Set 7 | swift current
# Processing Record 21 of Set 7 | kuhdasht
# Processing Record 22 of Set 7 | tecpan
# Processing Record 23 of Set 7 | haines junction
# Processing Record 24 of Set 7 | vao
# Processing Record 25 of Set 7 | guerrero negro
# Processing Record 26 of Set 7 | havelock
# Processing Record 27 of Set 7 | eureka
# Processing Record 28 of Set 7 | maamba
# Processing Record 29 of Set 7 | pingliang
# Processing Record 30 of Set 7 | salinas
# Processing Record 31 of Set 7 | kazuno
# Processing Record 32 of Set 7 | luanda
# Processing Record 33 of Set 7 | saint anthony
# Processing Record 34 of Set 7 | fortuna
# Processing Record 35 of Set 7 | ribeira grande
# Processing Record 36 of Set 7 | brae
# Processing Record 37 of Set 7 | gazanjyk
# Processing Record 38 of Set 7 | nhulunbuy
# Processing Record 39 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 7 | arcata
# Processing Record 41 of Set 7 | carballo
# Processing Record 42 of Set 7 | ust-ilimsk
# Processing Record 43 of Set 7 | suntar
# Processing Record 44 of Set 7 | boras
# Processing Record 45 of Set 7 | nemuro
# Processing Record 46 of Set 7 | flinders
# Processing Record 47 of Set 7 | xian
# Processing Record 48 of Set 7 | phultala
# Processing Record 49 of Set 7 | aykhal
# Processing Record 50 of Set 7 | fort walton beach
# Processing Record 1 of Set 8 | uzunovo
# Processing Record 2 of Set 8 | sabha
# Processing Record 3 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 8 | buraydah
# Processing Record 5 of Set 8 | beringovskiy
# Processing Record 6 of Set 8 | koslan
# Processing Record 7 of Set 8 | dunmore east
# Processing Record 8 of Set 8 | tetiz
# Processing Record 9 of Set 8 | lephepe
# City not found. Skipping...
# Processing Record 10 of Set 8 | ulladulla
# Processing Record 11 of Set 8 | jalu
# Processing Record 12 of Set 8 | dingle
# Processing Record 13 of Set 8 | arman
# Processing Record 14 of Set 8 | mitoc
# Processing Record 15 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 16 of Set 8 | evensk
# Processing Record 17 of Set 8 | lahti
# Processing Record 18 of Set 8 | batagay
# Processing Record 19 of Set 8 | teahupoo
# Processing Record 20 of Set 8 | kawambwa
# Processing Record 21 of Set 8 | baykit
# Processing Record 22 of Set 8 | swindon
# Processing Record 23 of Set 8 | ukiah
# Processing Record 24 of Set 8 | orcopampa
# Processing Record 25 of Set 8 | pultusk
# Processing Record 26 of Set 8 | sigli
# Processing Record 27 of Set 8 | warrington
# Processing Record 28 of Set 8 | makaha
# Processing Record 29 of Set 8 | tatarsk
# Processing Record 30 of Set 8 | rio gallegos
# Processing Record 31 of Set 8 | kutum
# Processing Record 32 of Set 8 | shuangcheng
# Processing Record 33 of Set 8 | lagoa
# Processing Record 34 of Set 8 | coahuayana
# Processing Record 35 of Set 8 | araguatins
# City not found. Skipping...
# Processing Record 36 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 37 of Set 8 | ginir
# Processing Record 38 of Set 8 | altay
# Processing Record 39 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 40 of Set 8 | solnechnyy
# Processing Record 41 of Set 8 | grand-lahou
# Processing Record 42 of Set 8 | ojinaga
# Processing Record 43 of Set 8 | catuday
# Processing Record 44 of Set 8 | corinto
# Processing Record 45 of Set 8 | skjeberg
# Processing Record 46 of Set 8 | bairiki
# Processing Record 47 of Set 8 | monrovia
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | manggar
# Processing Record 50 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 9 | hami
# Processing Record 2 of Set 9 | iratosu
# Processing Record 3 of Set 9 | saint-pierre
# Processing Record 4 of Set 9 | geraldton
# Processing Record 5 of Set 9 | saint-augustin
# Processing Record 6 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 9 | pleshanovo
# Processing Record 8 of Set 9 | boueni
# Processing Record 9 of Set 9 | antoniny
# Processing Record 10 of Set 9 | moulmeingyun
# City not found. Skipping...
# Processing Record 11 of Set 9 | pacific grove
# Processing Record 12 of Set 9 | djibo
# Processing Record 13 of Set 9 | ballina
# Processing Record 14 of Set 9 | kolokani
# Processing Record 15 of Set 9 | panjab
# Processing Record 16 of Set 9 | paragominas
# Processing Record 17 of Set 9 | kholodnyy
# Processing Record 18 of Set 9 | marzuq
# Processing Record 19 of Set 9 | xam nua
# Processing Record 20 of Set 9 | yumen
# Processing Record 21 of Set 9 | udachnyy
# Processing Record 22 of Set 9 | council bluffs
# Processing Record 23 of Set 9 | billings
# Processing Record 24 of Set 9 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 25 of Set 9 | kaoma
# Processing Record 26 of Set 9 | la union
# Processing Record 27 of Set 9 | roma
# Processing Record 28 of Set 9 | buin
# Processing Record 29 of Set 9 | alice springs
# Processing Record 30 of Set 9 | roebourne
# Processing Record 31 of Set 9 | mecca
# Processing Record 32 of Set 9 | itarema
# Processing Record 33 of Set 9 | minuri
# Processing Record 34 of Set 9 | portree
# Processing Record 35 of Set 9 | rocha
# Processing Record 36 of Set 9 | caluquembe
# Processing Record 37 of Set 9 | ermua
# Processing Record 38 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 9 | chekhov
# Processing Record 41 of Set 9 | nordby
# Processing Record 42 of Set 9 | constitucion
# Processing Record 43 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 9 | takoradi
# Processing Record 45 of Set 9 | moree
# Processing Record 46 of Set 9 | amahai
# Processing Record 47 of Set 9 | puteyets
# Processing Record 48 of Set 9 | lagunas
# Processing Record 49 of Set 9 | kitgum
# Processing Record 50 of Set 9 | cervo
# Processing Record 1 of Set 10 | kokoda
# Processing Record 2 of Set 10 | redmond
# Processing Record 3 of Set 10 | mehriz
# Processing Record 4 of Set 10 | iranshahr
# Processing Record 5 of Set 10 | byron bay
# Processing Record 6 of Set 10 | guipavas
# Processing Record 7 of Set 10 | creel
# Processing Record 8 of Set 10 | price
# Processing Record 9 of Set 10 | houston
# Processing Record 10 of Set 10 | saint-joseph
# Processing Record 11 of Set 10 | brezova pod bradlom
# Processing Record 12 of Set 10 | hoopstad
# Processing Record 13 of Set 10 | agadez
# Processing Record 14 of Set 10 | atar
# Processing Record 15 of Set 10 | scarborough
# Processing Record 16 of Set 10 | asosa
# Processing Record 17 of Set 10 | los banos
# Processing Record 18 of Set 10 | gurupi
# Processing Record 19 of Set 10 | yantal
# Processing Record 20 of Set 10 | sakakah
# Processing Record 21 of Set 10 | biak
# Processing Record 22 of Set 10 | dhemaji
# Processing Record 23 of Set 10 | banda aceh
# Processing Record 24 of Set 10 | boshnyakovo
# Processing Record 25 of Set 10 | tambopata
# Processing Record 26 of Set 10 | debre sina
# Processing Record 27 of Set 10 | guantanamo
# Processing Record 28 of Set 10 | antalaha
# Processing Record 29 of Set 10 | alyangula
# Processing Record 30 of Set 10 | port hardy
# Processing Record 31 of Set 10 | dwarka
# Processing Record 32 of Set 10 | tigil
# Processing Record 33 of Set 10 | arlit
# Processing Record 34 of Set 10 | ornskoldsvik
# Processing Record 35 of Set 10 | kiri buru
# Processing Record 36 of Set 10 | axim
# Processing Record 37 of Set 10 | karaton
# Processing Record 38 of Set 10 | rudnogorsk
# Processing Record 39 of Set 10 | kondinskoye
# Processing Record 40 of Set 10 | villa del rosario
# Processing Record 41 of Set 10 | zhanaozen
# Processing Record 42 of Set 10 | comodoro rivadavia
# Processing Record 43 of Set 10 | teseney
# Processing Record 44 of Set 10 | namwala
# Processing Record 45 of Set 10 | venice
# Processing Record 46 of Set 10 | ariquemes
# Processing Record 47 of Set 10 | hirara
# Processing Record 48 of Set 10 | sao joao da barra
# Processing Record 49 of Set 10 | mastic beach
# Processing Record 50 of Set 10 | oriximina
# Processing Record 1 of Set 11 | daru
# Processing Record 2 of Set 11 | fulton
# Processing Record 3 of Set 11 | lodwar
# Processing Record 4 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 11 | mao
# Processing Record 6 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 11 | uthal
# Processing Record 8 of Set 11 | zhuhai
# Processing Record 9 of Set 11 | dawei
# Processing Record 10 of Set 11 | follonica
# Processing Record 11 of Set 11 | phan thiet
# Processing Record 12 of Set 11 | tomatlan
# Processing Record 13 of Set 11 | karaman
# Processing Record 14 of Set 11 | kapustin yar-1
# City not found. Skipping...
# Processing Record 15 of Set 11 | mount isa
# Processing Record 16 of Set 11 | andenes
# Processing Record 17 of Set 11 | lucelia
# Processing Record 18 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 11 | asau
# Processing Record 20 of Set 11 | souillac
# Processing Record 21 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 11 | inongo
# Processing Record 23 of Set 11 | duldurga
# Processing Record 24 of Set 11 | abu samrah
# Processing Record 25 of Set 11 | flagstaff
# Processing Record 26 of Set 11 | lahat
# Processing Record 27 of Set 11 | tawang
# Processing Record 28 of Set 11 | oussouye
# Processing Record 29 of Set 11 | honningsvag
# Processing Record 30 of Set 11 | kysyl-syr
# Processing Record 31 of Set 11 | rehoboth
# Processing Record 32 of Set 11 | rio grande
# Processing Record 33 of Set 11 | todos santos
# Processing Record 34 of Set 11 | wladyslawowo
# Processing Record 35 of Set 11 | sajoszentpeter
# Processing Record 36 of Set 11 | srikakulam
# Processing Record 37 of Set 11 | aklavik
# Processing Record 38 of Set 11 | magistralnyy
# Processing Record 39 of Set 11 | saldanha
# Processing Record 40 of Set 11 | castiglione del lago
# Processing Record 41 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 42 of Set 11 | greenwood
# Processing Record 43 of Set 11 | russell
# Processing Record 44 of Set 11 | dinghai
# Processing Record 45 of Set 11 | harnosand
# Processing Record 46 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 11 | san patricio
# Processing Record 48 of Set 11 | paramonga
# Processing Record 49 of Set 11 | salt
# Processing Record 50 of Set 11 | ushtobe
# Processing Record 1 of Set 12 | ucluelet
# Processing Record 2 of Set 12 | westport
# Processing Record 3 of Set 12 | mount pleasant
# Processing Record 4 of Set 12 | havre-saint-pierre
# Processing Record 5 of Set 12 | laguna
# Processing Record 6 of Set 12 | santa vitoria do palmar
# Processing Record 7 of Set 12 | ciudad real
# Processing Record 8 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 9 of Set 12 | road town
# Processing Record 10 of Set 12 | demak
# Processing Record 11 of Set 12 | murdochville
# Processing Record 12 of Set 12 | polyarnyy
# Processing Record 13 of Set 12 | macaparana
# Processing Record 14 of Set 12 | nileshwar
# Processing Record 15 of Set 12 | huangzhai
# Processing Record 16 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 12 | sorong
# Processing Record 18 of Set 12 | rosita
# Processing Record 19 of Set 12 | nchelenge
# Processing Record 20 of Set 12 | dhidhdhoo
# Processing Record 21 of Set 12 | gainesville
# Processing Record 22 of Set 12 | cavalcante
# Processing Record 23 of Set 12 | portales
# Processing Record 24 of Set 12 | manono
# Processing Record 25 of Set 12 | madingou
# Processing Record 26 of Set 12 | nador
# Processing Record 27 of Set 12 | nakhon phanom
# Processing Record 28 of Set 12 | karonga
# Processing Record 29 of Set 12 | luau
# Processing Record 30 of Set 12 | old saybrook
# Processing Record 31 of Set 12 | dawlatabad
# Processing Record 32 of Set 12 | trebukhiv
# Processing Record 33 of Set 12 | solca
# Processing Record 34 of Set 12 | itabirito
# Processing Record 35 of Set 12 | nisia floresta
# Processing Record 36 of Set 12 | algiers
# Processing Record 37 of Set 12 | shahrud
# Processing Record 38 of Set 12 | kalur kot
# Processing Record 39 of Set 12 | rumoi
# Processing Record 40 of Set 12 | tsiroanomandidy
# Processing Record 41 of Set 12 | voyvozh
# Processing Record 42 of Set 12 | hvide sande
# Processing Record 43 of Set 12 | kabwe
# Processing Record 44 of Set 12 | gamba
# Processing Record 45 of Set 12 | linhares
# Processing Record 46 of Set 12 | vanavara
# Processing Record 47 of Set 12 | penzance
# Processing Record 48 of Set 12 | nayoro
# Processing Record 49 of Set 12 | roseau
# Processing Record 50 of Set 12 | kawalu
# Processing Record 1 of Set 13 | cape coast
# Processing Record 2 of Set 13 | bar harbor
# Processing Record 3 of Set 13 | touros
# Processing Record 4 of Set 13 | pokhara
# Processing Record 5 of Set 13 | lucea
# Processing Record 6 of Set 13 | mabaruma
# Processing Record 7 of Set 13 | necochea
# Processing Record 8 of Set 13 | mezhdurechensk
# Processing Record 9 of Set 13 | ambon
# Processing Record 10 of Set 13 | eldorado
# Processing Record 11 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 13 | york
# Processing Record 13 of Set 13 | buchanan
# Processing Record 14 of Set 13 | mandalgovi
# Processing Record 15 of Set 13 | mandali
# Processing Record 16 of Set 13 | henties bay
# Processing Record 17 of Set 13 | hofn
# Processing Record 18 of Set 13 | paamiut
# Processing Record 19 of Set 13 | mizdah
# Processing Record 20 of Set 13 | kailua
# Processing Record 21 of Set 13 | nanortalik
# Processing Record 22 of Set 13 | huanren
# Processing Record 23 of Set 13 | perth
# Processing Record 24 of Set 13 | makakilo city
# Processing Record 25 of Set 13 | adrar
# Processing Record 26 of Set 13 | tuy hoa
# Processing Record 27 of Set 13 | broken hill
# Processing Record 28 of Set 13 | sitrah
# Processing Record 29 of Set 13 | the valley
# Processing Record 30 of Set 13 | luderitz
# Processing Record 31 of Set 13 | novorzhev
# Processing Record 32 of Set 13 | naze
# Processing Record 33 of Set 13 | chapais
# Processing Record 34 of Set 13 | bahce
# Processing Record 35 of Set 13 | sechura
# Processing Record 36 of Set 13 | tamasane
# Processing Record 37 of Set 13 | shache
# Processing Record 38 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 13 | casa nova
# Processing Record 41 of Set 13 | yakeshi
# Processing Record 42 of Set 13 | fuerte olimpo
# Processing Record 43 of Set 13 | gorontalo
# Processing Record 44 of Set 13 | vardo
# Processing Record 45 of Set 13 | bulgan
# Processing Record 46 of Set 13 | celestun
# Processing Record 47 of Set 13 | awbari
# Processing Record 48 of Set 13 | jacmel
# Processing Record 49 of Set 13 | kibre mengist
# Processing Record 50 of Set 13 | waw
# Processing Record 1 of Set 14 | benguela
# Processing Record 2 of Set 14 | pemba
# Processing Record 3 of Set 14 | qandala
# Processing Record 4 of Set 14 | kargasok
# Processing Record 5 of Set 14 | bundaberg
# Processing Record 6 of Set 14 | sagar
# Processing Record 7 of Set 14 | tromso
# Processing Record 8 of Set 14 | hay river
# Processing Record 9 of Set 14 | lufkin
# Processing Record 10 of Set 14 | podgornoye
# Processing Record 11 of Set 14 | araceli
# Processing Record 12 of Set 14 | half moon bay
# Processing Record 13 of Set 14 | lincoln
# Processing Record 14 of Set 14 | canutama
# Processing Record 15 of Set 14 | kupang
# Processing Record 16 of Set 14 | hobyo
# Processing Record 17 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set 14 | aksu
# Processing Record 19 of Set 14 | sorland
# Processing Record 20 of Set 14 | vilaka
# Processing Record 21 of Set 14 | astaneh-ye ashrafiyeh
# Processing Record 22 of Set 14 | aden
# Processing Record 23 of Set 14 | mahajanga
# Processing Record 24 of Set 14 | alofi
# Processing Record 25 of Set 14 | salinopolis
# Processing Record 26 of Set 14 | bajil
# Processing Record 27 of Set 14 | aransas pass
# Processing Record 28 of Set 14 | quatre cocos
# Processing Record 29 of Set 14 | lorengau
# Processing Record 30 of Set 14 | vila franca do campo
# Processing Record 31 of Set 14 | bangassou
# Processing Record 32 of Set 14 | brokopondo
# Processing Record 33 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 14 | matto
# City not found. Skipping...
# Processing Record 35 of Set 14 | megion
# Processing Record 36 of Set 14 | tabou
# Processing Record 37 of Set 14 | morro bay
# Processing Record 38 of Set 14 | ampanihy
# Processing Record 39 of Set 14 | santa maria do suacui
# Processing Record 40 of Set 14 | lithgow
# Processing Record 41 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 14 | port keats
# Processing Record 43 of Set 14 | juneau
# Processing Record 44 of Set 14 | opuwo
# Processing Record 45 of Set 14 | plyussa
# Processing Record 46 of Set 14 | buritizeiro
# Processing Record 47 of Set 14 | amboasary
# Processing Record 48 of Set 14 | aksha
# Processing Record 49 of Set 14 | perbaungan
# Processing Record 50 of Set 14 | zhanakorgan
# Processing Record 1 of Set 15 | sao miguel do araguaia
# Processing Record 2 of Set 15 | kyabram
# Processing Record 3 of Set 15 | parkes
# Processing Record 4 of Set 15 | komsomolskiy
# Processing Record 5 of Set 15 | itamaraca
# Processing Record 6 of Set 15 | bahia honda
# Processing Record 7 of Set 15 | mitsamiouli
# Processing Record 8 of Set 15 | boende
# Processing Record 9 of Set 15 | goderich
# Processing Record 10 of Set 15 | kita
# Processing Record 11 of Set 15 | sault sainte marie
# Processing Record 12 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 15 | bilibino
# Processing Record 14 of Set 15 | fonte boa
# Processing Record 15 of Set 15 | baghdad
# Processing Record 16 of Set 15 | jambi
# Processing Record 17 of Set 15 | sokyryany
# Processing Record 18 of Set 15 | bafoulabe
# Processing Record 19 of Set 15 | suzdal
# Processing Record 20 of Set 15 | hargeysa
# Processing Record 21 of Set 15 | talnakh
# Processing Record 22 of Set 15 | portland
# Processing Record 23 of Set 15 | talpa
# Processing Record 24 of Set 15 | huarmey
# Processing Record 25 of Set 15 | imbituba
# Processing Record 26 of Set 15 | general roca
# Processing Record 27 of Set 15 | vostok
# Processing Record 28 of Set 15 | quelimane
# Processing Record 29 of Set 15 | balabac
# Processing Record 30 of Set 15 | prince rupert
# Processing Record 31 of Set 15 | manado
# Processing Record 32 of Set 15 | samarai
# Processing Record 33 of Set 15 | boralday
# Processing Record 34 of Set 15 | thinadhoo
# Processing Record 35 of Set 15 | maple creek
# Processing Record 36 of Set 15 | port augusta
# Processing Record 37 of Set 15 | tessalit
# Processing Record 38 of Set 15 | nelipyno
# Processing Record 39 of Set 15 | knysna
# Processing Record 40 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 15 | port pirie
# Processing Record 42 of Set 15 | villa carlos paz
# Processing Record 43 of Set 15 | waingapu
# Processing Record 44 of Set 15 | evansville
# Processing Record 45 of Set 15 | port hedland
# Processing Record 46 of Set 15 | taksimo
# Processing Record 47 of Set 15 | anadyr
# Processing Record 48 of Set 15 | wagga wagga
# Processing Record 49 of Set 15 | polunochnoye
# Processing Record 50 of Set 15 | khani
# Processing Record 1 of Set 16 | talara
# Processing Record 2 of Set 16 | avera
# Processing Record 3 of Set 16 | gladstone
# Processing Record 4 of Set 16 | sinazongwe
# Processing Record 5 of Set 16 | buala
# Processing Record 6 of Set 16 | sacramento
# Processing Record 7 of Set 16 | komyshuvakha
# Processing Record 8 of Set 16 | otradnoye
# Processing Record 9 of Set 16 | omboue
# Processing Record 10 of Set 16 | pout
# Processing Record 11 of Set 16 | yushan
# Processing Record 12 of Set 16 | kiruna
# Processing Record 13 of Set 16 | nha trang
# Processing Record 14 of Set 16 | isiro
# Processing Record 15 of Set 16 | yinchuan
# Processing Record 16 of Set 16 | acapulco
# Processing Record 17 of Set 16 | siderno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 716

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Eydhafushi   5.1033   73.0708     80.46        75           9
# 1    Punta Arenas -53.1500  -70.9167     53.71        35           0
# 2       Busselton -33.6500  115.3333     61.16        51          13
# 3        Cidreira -30.1811  -50.2056     74.55        80          95
# 4       Pringsewu  -5.3582  104.9744     74.57        92         100
# 5         Kavieng  -2.5744  150.7967     82.80        70         100
# 6  Port Macquarie -31.4333  152.9167     72.90        72          67
# 7         Iqaluit  63.7506  -68.5145    -25.31        74           0
# 8        Cherskiy  68.7500  161.3000    -35.90        96         100
# 9           Bluff -46.6000  168.3333     60.87        72          28
#
#    Wind Speed Country       Description
# 0       11.79      MV         clear sky
# 1       27.63      CL         clear sky
# 2       11.63      AU        few clouds
# 3       11.07      BR   overcast clouds
# 4        1.63      ID     moderate rain
# 5        5.10      PG        light rain
# 6        3.91      AU     broken clouds
# 7        0.00      CA         clear sky
# 8        3.58      RU   overcast clouds
# 9        8.93      NZ  scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Eydhafushi      MV   5.1033   73.0708     80.46        75           9
# 1    Punta Arenas      CL -53.1500  -70.9167     53.71        35           0
# 2       Busselton      AU -33.6500  115.3333     61.16        51          13
# 3        Cidreira      BR -30.1811  -50.2056     74.55        80          95
# 4       Pringsewu      ID  -5.3582  104.9744     74.57        92         100
# 5         Kavieng      PG  -2.5744  150.7967     82.80        70         100
# 6  Port Macquarie      AU -31.4333  152.9167     72.90        72          67
# 7         Iqaluit      CA  63.7506  -68.5145    -25.31        74           0
# 8        Cherskiy      RU  68.7500  161.3000    -35.90        96         100
# 9           Bluff      NZ -46.6000  168.3333     60.87        72          28
#
#    Wind Speed       Description
# 0       11.79         clear sky
# 1       27.63         clear sky
# 2       11.63        few clouds
# 3       11.07   overcast clouds
# 4        1.63     moderate rain
# 5        5.10        light rain
# 6        3.91     broken clouds
# 7        0.00         clear sky
# 8        3.58   overcast clouds
# 9        8.93  scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file= "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label= "City_ID")
